# %%
import sys

sys.path.append("../src")
sys.path.append("..")

# %%
import matplotlib.pyplot as plt
import networkx as nx

# %%
from app import test_case_1

# %%
test_case_1()
# Out:
# /workspaces/deep_learning/scratchpad
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 test_case_1()
#
# File /workspaces/deep_learning/scratchpad/../src/app.py:162, in test_case_1()
#     160 import os
#     161 print(os.getcwd())
# --> 162 with open('..data/robots/robots1.json', 'r') as f:
#     163     robots = json.load(f)
#     165     print(robots)
#
# FileNotFoundError: [Errno 2] No such file or directory: '..data/robots/robots1.json'

# %%
alg = test_case_1()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 alg = test_case_1()
#
# File /workspaces/deep_learning/scratchpad/../src/app.py:112, in test_case_1()
#     101 orders = {
#     102     7: 1,
#     103     11: 1,
#    (...)
#     108     2: 2,
#     109 }
#     111 path = Path('generated_graphs/graph_10_10.adjlist')
# --> 112 warehouse = Warehouse(
#     113     txt_file=path, robots=robots)
#     115 alg = AntAlgorithm.from_orders_warehouse(orders, warehouse)
#     116 solution = alg.solve(
#     117     iter=1000,
#     118     alpha=0.1,
#     119     beta=0.1,
#     120     decay_rate=0.01
#     121 )
#
# File /workspaces/deep_learning/scratchpad/../src/objects/warehouse.py:9, in Warehouse.__init__(self, txt_file, robots)
#       8 def __init__(self, txt_file: Path, robots: List[Robot]) -> None:
# ----> 9     self.graph = nx.read_adjlist(txt_file)
#      10     self.robots = robots
#
# File <class 'networkx.utils.decorators.argmap'> compilation 5:3, in argmap_read_adjlist_1(path, comments, delimiter, create_using, nodetype, encoding, backend, **backend_kwargs)
#       1 import bz2
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#       5 import itertools
#
# File /usr/local/lib/python3.10/site-packages/networkx/utils/decorators.py:193, in open_file.<locals>._open_file(path)
#     189 else:
#     190     # could be None, or a file handle, in which case the algorithm will deal with it
#     191     return path, lambda: None
# --> 193 fobj = _dispatch_dict[ext](path, mode=mode)
#     194 return fobj, lambda: fobj.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'generated_graphs/graph_10_10.adjlist'

# %%
def plot(i):
    G=nx.Graph(name="buba")

    routes = [alg.runtime_data['best_solutions'][-1][i]['path']]
    edges = []
    for r in routes:
        route_edges = [(r[n],r[n+1]) for n in range(len(r)-1)]
        G.add_nodes_from(r)
        G.add_edges_from(route_edges)
        edges.append(route_edges)

    print("Graph has %d nodes with %d edges" %(G.number_of_nodes(),    
    G.number_of_edges()))

    pos = nx.spring_layout(G)
    nx.draw_networkx_nodes(G,pos=pos)
    nx.draw_networkx_labels(G,pos=pos)
    colors = ['r', 'b', 'y']
    linewidths = [5,3,2]
    for ctr, edgelist in enumerate(edges):
        nx.draw_networkx_edges(G,pos=pos,edgelist=edgelist,edge_color = colors[ctr], width=linewidths[ctr])

    plt.show()

# %%
for i in range(len(alg.ants)):
    plot(i)
# Out:
# Graph has 4 nodes with 4 edges
# Graph has 5 nodes with 5 edges
# Graph has 3 nodes with 2 edges

# %%
data = alg.runtime_data['best_scores'] + [(alg.runtime_data['params']['iter'], alg.runtime_data['best_scores'][-1][1])]
x = [point[0] for point in data]
y = [point[1] for point in data]

# Create a step plot
plt.step(x, y, where='post')

# Title and labels
plt.title('Step Plot of Data')
plt.xlabel('X')
plt.ylabel('Y')

# Show plot
plt.show()
